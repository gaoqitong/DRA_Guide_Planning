# %%
from __future__ import division
from full_prod_DRA import *
from buchi import buchi_from_ltl
import numpy as np
from env_sensing_error import *
import scipy
# from plot_path_for_prod import *
from graphviz import Source
from qnetwork import *
from utils import *
import matplotlib.pyplot as plt
# from Plot_Path import *
import tensorflow as tf
import sys
from dra_planning import *
import time
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p27/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
def train(sess, env, qnet, prod_planner):
    
    global EXPLORATION_RATE
    global GUIDE_RATE
  
    summary_ops, summary_vars = build_summaries()
    if not RESTORE:
        sess.run(tf.global_variables_initializer())
    writer = tf.summary.FileWriter(SUMMARY_DIR, sess.graph)
    
    qnet.update_target()
    
    replay_buffer = ReplayBuffer(BUFFER_SIZE, RANDOM_SEED)
    
    while len(prod_planner.opt_path) == 0:
        env.step(np.random.randint(0,qnet.action_dim))
        prod_planner.update_wfts_ap()
        prod_planner.get_global_opt()
    print "Global Solution Found"
    prod_planner.get_opt_rabin()
    
    saved_dra_planners = {}
    
    for num_epi in range(MAX_EPISODES):
        
#         print "Epi: ", num_epi

        s = env.reset()
        s = list(np.unravel_index(s, env.shape))
        prod_planner.replace_region_list()

        ep_reward = 0
        ep_ave_max_q = 0
        
        reward_list = []
        
        train_time = 0
        batch_time = 0
        gym_time = 0
        guide_time = 0

        for j in range(MAX_EPISODE_LEN):
            
#             print "Step: ", j
            
            gym_start = time.time()

            rand_num = np.random.rand(1)
    
            if rand_num <= EXPLORATION_RATE:
                a = np.random.randint(0,qnet.action_dim)
                s2, r, terminal, info = env.step(a)
                
            elif rand_num <= GUIDE_RATE+EXPLORATION_RATE and rand_num > EXPLORATION_RATE:
#                 print "GUIDE"
                guide_start = time.time()
                
                if rand_num > EXPLORATION_RATE + 0.9*GUIDE_RATE:
                # Only update global plan with 0.2 prob for efficiency
                    prod_planner.get_global_opt()
                    prod_planner.get_opt_rabin()
                    
                if len(prod_planner.opt_path) > 0:
#                     print "S: ", s
#                     print "last a: ", a
                    new_ltl = prod_planner.get_next_ltl(s[-1])
                    
#                     if new_ltl in saved_dra_planners.keys():
                    guide_path = prod_planner.get_local_opt(s[:-1], new_ltl)
                    if guide_path != None:
                        print "GUIDE"
                        a = convert_path_to_action(guide_path)
                    else:
                        a = np.random.randint(0,qnet.action_dim)
#                     else:
#                         guide_path = prod_planner.get_local_opt(s[:-1], new_ltl)
#                         saved_dra_planners[new_ltl] = prod_planner.dra_full_prod
#                         if guide_path != None:
#                             a = convert_path_to_action(guide_path)
#                         else:
#                             a = np.random.randint(0,qnet.action_dim)
                        
                else:
                    a = np.random.randint(0,qnet.action_dim)
                
                s2, r, terminal, info = env.step(a)
                
                guide_time += time.time() - guide_start
                
            else:
                a = np.argmax(qnet.predict_q(np.reshape(s, (1, qnet.state_dim))))
                s2, r, terminal, info = env.step(a)

            prod_planner.update_wfts_ap()
                
            gym_time += time.time() - gym_start
            
            batch_start = time.time()
            
            s2 = list(np.unravel_index(s2, env.shape))

            replay_buffer.add(np.reshape(s, (qnet.state_dim,)), np.reshape(a, (1,)), r,
                              terminal, np.reshape(s2, (qnet.state_dim,)))
            batch_time += time.time() - batch_start

            # Keep adding experience to the memory until
            # there are at least minibatch size samples
            if replay_buffer.size() > MINIBATCH_SIZE:
                
                batch_start = time.time()
                s_batch, a_batch, r_batch, t_batch, s2_batch = replay_buffer.sample_batch(MINIBATCH_SIZE)
                print "sbatch: ", s_batch
                # Calculate targets
                target_q = qnet.predect_target(s2_batch)

                y_i = []
                for k in range(MINIBATCH_SIZE):
                    if t_batch[k]:
                        y_i.append(r_batch[k])
                    else:
                        y_i.append(r_batch[k] + GAMMA * np.amax(target_q[k]))
                        
                batch_time += time.time() - batch_start

                # Update the critic given the targets
                train_start = time.time()
                predicted_q_value, _ = qnet.train(s_batch, a_batch, np.reshape(y_i, (MINIBATCH_SIZE, 1)), num_epi)

                ep_ave_max_q += np.amax(predicted_q_value)
                
                # Update target networks
                qnet.update_target()

                train_time += time.time() - train_start

            s = s2
            ep_reward += r

            if terminal or j == MAX_EPISODE_LEN-1:
                
                if EXPLORATION_RATE > 0.02 and terminal:
                    EXPLORATION_RATE = EXPLORATION_RATE*0.98
                    GUIDE_RATE = GUIDE_RATE*0.98
                    
                reward_list += [ep_reward]
                
                if np.average(reward_list[-10:]) > LR_DECAY_TRUNCATION:
                    qnet.decay_learning_rate(0.98)

                print('| Reward: {:d} | Episode: {:d} | Qmax: {:.4f} | Exploration: {:.6f} | Step: {:d} | LR: {:.8f}'.format(int(ep_reward), \
                        num_epi, (ep_ave_max_q / float(j)), EXPLORATION_RATE, j, qnet.get_learning_rate()))
                
                f = open("stats/" + file_appendix + "_stats.txt", "ab")
                f.write("| Reward: " + str(int(ep_reward)) 
                        +" | Episode: " + str(num_epi) 
                        + " | Qmax: " + str(ep_ave_max_q / float(j)) 
                        + " | Exploration: " + str(EXPLORATION_RATE)
                        + " | Step: " + str(j)
                        + " | LR:" + str(qnet.get_learning_rate()) + "\n")
                f.close()
                
                f = open("stats/" + file_appendix + "_stats_time.txt", "ab")
                f.write(" | Episode: " + str(num_epi) 
                        + " | Train: " + str(train_time) 
                        + " | Gym: " + str(gym_time)
                        + " | Batch: " + str(batch_time) 
                        + " | Guide: " + str(guide_time)
                        + "\n")
                f.close()
                
                break

# %%
# LTL = "<>(A && <>(B && <> T)) && []<>A && []<>B"
# LTL = "[] (p1 -> !(X p1) U (p2 || p3) ) && []<>p1"
# LTL = "T && []<>A && []<>B"
# LTL = "<>(A && <>(B && <> T)) && []<>A && []<>B && []!C && []!D"
# LTL = "<>(A && <>(B && <> T)) && []<>A && []<>B && []!C"
# LTL = "<>(A && <>(B && <> T))"
# LTL = "<>(A && <>B) && <>[]T && []!C"
LTL = "<>(A && <>T) && []!C"
# LTL = "<>(A && <>(B && <>T)) && []<>(A||T) && []<>B && []!C"
# LTL = "<>(A && <>(B && <>T)) && []!C"
# LTL = "<>(A && <>D) && <>(B && <>E) && []<>T && []<>(D || E) && []!C"

LEARNING_RATE = 0.00001
GAMMA = 0.99
# GAMMA = 0.7
TAU = 0.001
BUFFER_SIZE = 10**6
MINIBATCH_SIZE = 64
RANDOM_SEED = 210
MAX_EPISODES = 50000
MAX_EPISODE_LEN = 500
file_appendix = "Guide_Planning_" + time.ctime()[4:16].replace("  ","").replace(" ","_").replace(":","-") + "_large_" + LTL
# file_appendix = "Feb8_03-47"
SUMMARY_DIR = './results/tf_ddqn_' + file_appendix
SAVE_DIR = "./saved_model/" + file_appendix + "/ddqn.ckpt"
EXPLORATION_RATE = 0.2
GUIDE_RATE = 0.6
LR_DECAY_TRUNCATION = -200
RESTORE = 0
if sys.platform == "darwin":
    DEVICE = "/device:CPU:0"
else:
    DEVICE = "/device:GPU:0"

# %%
env = CurrentWorld(LTL)
prod_planner = Prod_Planning(env, LTL)
# with open("my.dot", "r") as dotfile:
#     text = dotfile.read()
# Source(text)

# %%
config=tf.ConfigProto(log_device_placement=False)
config.gpu_options.allow_growth = True
with tf.Session(config=config) as sess:
       
    state_dim = 3
    action_dim = 5
    
    if RESTORE:
        Qnet = QNet(sess, state_dim, action_dim, LEARNING_RATE, TAU, MINIBATCH_SIZE, SAVE_DIR, DEVICE)
        Qnet.saver.restore(sess, RESTORE_PATH)
        train(sess, env, Qnet, prod_planner)
        
    else:
        np.random.seed(RANDOM_SEED)
        tf.set_random_seed(RANDOM_SEED)
        env.seed(RANDOM_SEED)
    
        Qnet = QNet(sess, state_dim, action_dim, LEARNING_RATE, TAU, MINIBATCH_SIZE, SAVE_DIR, DEVICE)

        train(sess, env, Qnet, prod_planner)
# Out:
# Global Solution Found
# sbatch:  [[4 0 1]]
# DDQN Saved
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[4 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[4 0 1]]
# sbatch:  [[4 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 0 1]]
# sbatch:  [[5 0 1]]
# sbatch:  [[4 1 1]]
# sbatch:  [[4 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 0 1]]
# sbatch:  [[4 0 1]]
# sbatch:  [[6 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 1]]
# sbatch:  [[5 1 1]]
# sbatch:  [[7 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 0 1]]
# sbatch:  [[4 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[4 1 1]]
# sbatch:  [[5 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[4 1 1]]
# sbatch:  [[6 1 1]]
# sbatch:  [[8 3 1]]
# sbatch:  [[8 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 0 1]]
# sbatch:  [[5 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[4 0 1]]
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# sbatch:  [[4 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 5 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 3 1]]
# sbatch:  [[8 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 4 1]]
# sbatch:  [[8 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 3 1]]
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 0 1]]
# sbatch:  [[6 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 5 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[4 1 1]]
# sbatch:  [[7 1 1]]
# sbatch:  [[9 1 1]]
# sbatch:  [[8 3 1]]
# sbatch:  [[4 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 3 1]]
# sbatch:  [[9 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 5 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 2 1]]
# sbatch:  [[4 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 0 1]]
# sbatch:  [[9 3 1]]
# sbatch:  [[6 4 1]]
# sbatch:  [[6 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 0 1]]
# sbatch:  [[8 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 0 1]]
# sbatch:  [[6 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[4 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 4 1]]
# sbatch:  [[8 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 1 1]]
# sbatch:  [[8 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 4 1]]
# sbatch:  [[9 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 0 1]]
# sbatch:  [[7 1 1]]
# sbatch:  [[8 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[4 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 1 1]]
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 5 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[2 1 1]]
# sbatch:  [[6 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 4 1]]
# sbatch:  [[2 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# sbatch:  [[9 3 1]]
# sbatch:  [[7 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[1 3 1]]
# sbatch:  [[1 1 1]]
# sbatch:  [[9 1 1]]
# sbatch:  [[8 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[1 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[4 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[2 6 1]]
# sbatch:  [[9 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[4 1 1]]
# sbatch:  [[7 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 2 1]]
# sbatch:  [[1 1 1]]
# sbatch:  [[1 0 1]]
# sbatch:  [[1 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[1 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[3 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# sbatch:  [[1 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[1 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[0 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[1 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 1]]
# sbatch:  [[4 0 1]]
# sbatch:  [[8 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[1 6 1]]
# sbatch:  [[8 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# sbatch:  [[7 1 1]]
# sbatch:  [[8 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[0 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 0 1]]
# sbatch:  [[1 7 1]]
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  2
# sbatch:  [[8 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  2
# sbatch:  [[0 6 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  2
# sbatch:  [[0 4 1]]
# sbatch:  [[0 2 1]]
# sbatch:  [[7 1 1]]
# sbatch:  [[1 3 1]]
# sbatch:  [[9 1 1]]
# sbatch:  [[2 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  2
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  2
# sbatch:  [[5 9 2]]
# sbatch:  [[4 0 1]]
# sbatch:  [[8 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  2
# sbatch:  [[5 9 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  2
# sbatch:  [[1 6 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  2
# sbatch:  [[0 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  2
# sbatch:  [[4 0 1]]
# sbatch:  [[4 7 1]]
# sbatch:  [[1 4 1]]
# sbatch:  [[0 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  2
# sbatch:  [[8 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  2
# sbatch:  [[7 9 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  2
# sbatch:  [[0 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  3
# sbatch:  [[1 3 1]]
# sbatch:  [[1 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[4 0 1]]
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[7 1 1]]
# sbatch:  [[4 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[0 2 1]]
# sbatch:  [[8 2 1]]
# sbatch:  [[5 8 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[3 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 1 1]]
# sbatch:  [[9 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[0 9 1]]
# sbatch:  [[8 4 1]]
# sbatch:  [[8 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[4 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[1 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[1 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 3 1]]
# sbatch:  [[4 9 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[0 6 1]]
# sbatch:  [[1 6 1]]
# sbatch:  [[3 7 1]]
# sbatch:  [[8 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[1 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 5 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[7 9 2]]
# sbatch:  [[1 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[2 8 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[0 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[3 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[0 8 1]]
# sbatch:  [[4 8 2]]
# sbatch:  [[8 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 0 1]]
# sbatch:  [[4 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 8 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 0 1]]
# sbatch:  [[0 8 1]]
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[1 8 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[0 7 1]]
# sbatch:  [[4 0 1]]
# sbatch:  [[9 3 1]]
# sbatch:  [[3 7 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[0 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[1 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[1 3 1]]
# sbatch:  [[2 8 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[7 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 9 4]]
# sbatch:  [[4 1 1]]
# sbatch:  [[1 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[7 1 1]]
# sbatch:  [[0 3 1]]
# sbatch:  [[0 8 1]]
# sbatch:  [[9 4 4]]
# sbatch:  [[0 7 1]]
# sbatch:  [[9 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 6 4]]
# sbatch:  [[5 8 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[5 9 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[0 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 6 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[7 5 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 3 1]]
# sbatch:  [[7 7 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[7 8 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 9 4]]
# sbatch:  [[4 1 1]]
# sbatch:  [[8 0 1]]
# sbatch:  [[6 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[0 8 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[1 1 1]]
# sbatch:  [[2 9 1]]
# sbatch:  [[0 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 8 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 1 1]]
# sbatch:  [[0 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[6 1 1]]
# sbatch:  [[4 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[0 7 1]]
# sbatch:  [[7 5 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[0 8 1]]
# sbatch:  [[8 0 1]]
# sbatch:  [[9 2 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[0 6 1]]
# sbatch:  [[9 1 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[4 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[7 5 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[7 8 2]]
# sbatch:  [[0 8 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[5 8 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 3 4]]
# sbatch:  [[2 8 1]]
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[7 1 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[7 4 1]]
# sbatch:  [[5 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[7 0 4]]
# sbatch:  [[9 8 4]]
# sbatch:  [[0 6 1]]
# sbatch:  [[3 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[7 4 1]]
# sbatch:  [[0 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 1 4]]
# sbatch:  [[8 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 1 4]]
# sbatch:  [[0 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[4 7 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[7 6 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[1 1 1]]
# sbatch:  [[8 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[5 8 2]]
# sbatch:  [[7 1 4]]
# sbatch:  [[9 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 4 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[7 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[0 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[3 7 2]]
# sbatch:  [[8 5 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 0 4]]
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[0 6 1]]
# sbatch:  [[5 8 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 6 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[5 9 2]]
# sbatch:  [[5 9 2]]
# sbatch:  [[9 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 2 1]]
# sbatch:  [[0 6 1]]
# sbatch:  [[5 8 2]]
# sbatch:  [[0 6 1]]
# sbatch:  [[7 1 1]]
# sbatch:  [[6 7 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[0 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[1 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[4 8 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[2 9 1]]
# sbatch:  [[0 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 2 1]]
# sbatch:  [[7 7 4]]
# sbatch:  [[8 8 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 7 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 4 1]]
# sbatch:  [[1 8 1]]
# sbatch:  [[7 0 4]]
# sbatch:  [[1 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 3 4]]
# sbatch:  [[9 3 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[0 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 7 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 5 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[6 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[7 0 4]]
# sbatch:  [[4 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[0 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 2 1]]
# sbatch:  [[8 4 1]]
# sbatch:  [[7 2 4]]
# sbatch:  [[7 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[3 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[7 7 4]]
# sbatch:  [[7 8 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 6 4]]
# sbatch:  [[4 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 0 4]]
# sbatch:  [[9 3 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[7 0 4]]
# sbatch:  [[8 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 8 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[0 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 1 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 3 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 1 4]]
# sbatch:  [[9 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[7 8 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 0 1]]
# sbatch:  [[1 5 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[3 7 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[7 9 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 2 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 0 4]]
# sbatch:  [[8 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[1 9 1]]
# sbatch:  [[9 3 4]]
# sbatch:  [[9 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 8 4]]
# sbatch:  [[0 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 3 1]]
# sbatch:  [[9 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[7 3 1]]
# sbatch:  [[9 1 4]]
# sbatch:  [[0 6 1]]
# sbatch:  [[2 5 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[0 8 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[6 7 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 9 4]]
# sbatch:  [[9 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[0 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[2 9 1]]
# sbatch:  [[7 4 1]]
# sbatch:  [[9 3 4]]
# sbatch:  [[0 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 0 4]]
# sbatch:  [[0 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 0 4]]
# sbatch:  [[1 8 1]]
# sbatch:  [[8 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[7 8 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[2 8 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[7 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[5 9 2]]
# sbatch:  [[0 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[7 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[4 2 1]]
# sbatch:  [[9 6 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[7 1 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[0 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 2 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 0 4]]
# sbatch:  [[7 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 5 4]]
# sbatch:  [[4 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 0 4]]
# sbatch:  [[0 6 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 5 4]]
# sbatch:  [[7 8 4]]
# sbatch:  [[7 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 1 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[7 3 1]]
# sbatch:  [[8 2 4]]
# sbatch:  [[8 1 4]]
# sbatch:  [[9 5 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 1 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 5 4]]
# sbatch:  [[2 5 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[1 6 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[7 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[0 9 1]]
# sbatch:  [[7 1 4]]
# sbatch:  [[8 1 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 0 4]]
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[3 7 2]]
# sbatch:  [[1 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[6 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[1 8 1]]
# sbatch:  [[9 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 3 4]]
# sbatch:  [[8 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 2 4]]
# sbatch:  [[0 8 1]]
# sbatch:  [[5 9 1]]
# sbatch:  [[4 7 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 0 4]]
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 8 4]]
# sbatch:  [[9 5 4]]
# sbatch:  [[1 7 1]]
# sbatch:  [[6 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 5 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 2 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 6 4]]
# sbatch:  [[9 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 5 4]]
# sbatch:  [[4 0 1]]
# sbatch:  [[8 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 1 1]]
# sbatch:  [[9 2 4]]
# sbatch:  [[9 3 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[5 9 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 3 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[9 7 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 4 1]]
# sbatch:  [[8 1 1]]
# sbatch:  [[9 1 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[7 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 6 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[0 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 1 4]]
# sbatch:  [[9 8 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  4
# sbatch:  [[8 4 1]]
# | Reward: -2291 | Episode: 0 | Qmax: 13.9943 | Exploration: 0.200000 | Step: 499 | LR: 0.00001000
# sbatch:  [[8 5 4]]
# sbatch:  [[2 8 1]]
# sbatch:  [[9 3 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 4 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[0 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 2 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 9 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 8 4]]
# sbatch:  [[0 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 6 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 6 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 5 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 5 4]]
# sbatch:  [[8 5 1]]
# sbatch:  [[7 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 8 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[1 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 8 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[2 6 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[0 7 1]]
# sbatch:  [[9 2 4]]
# sbatch:  [[5 8 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 7 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 8 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[3 8 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 0 1]]
# sbatch:  [[7 5 4]]
# sbatch:  [[6 1 1]]
# sbatch:  [[1 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 4 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[1 3 1]]
# sbatch:  [[9 1 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[0 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 9 4]]
# sbatch:  [[4 0 1]]
# sbatch:  [[7 1 4]]
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 5 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 4 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 5 4]]
# sbatch:  [[9 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[4 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 4]]
# sbatch:  [[6 5 4]]
# sbatch:  [[9 1 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[0 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[0 7 1]]
# sbatch:  [[9 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 8 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[1 1 1]]
# sbatch:  [[9 2 1]]
# sbatch:  [[8 1 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 7 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 4 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 3 1]]
# sbatch:  [[7 7 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 6 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 7 4]]
# sbatch:  [[8 1 4]]
# sbatch:  [[8 0 1]]
# sbatch:  [[8 5 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[0 7 1]]
# sbatch:  [[5 9 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 5 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 5 4]]
# sbatch:  [[0 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 6 4]]
# sbatch:  [[9 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 3 1]]
# sbatch:  [[8 4 1]]
# sbatch:  [[9 2 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 0 1]]
# sbatch:  [[9 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[4 0 1]]
# sbatch:  [[8 2 1]]
# sbatch:  [[9 5 4]]
# sbatch:  [[9 5 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[3 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 1 1]]
# sbatch:  [[2 5 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 1]]
# sbatch:  [[8 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[3 7 2]]
# sbatch:  [[9 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 5 1]]
# sbatch:  [[7 1 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 4]]
# sbatch:  [[7 4 4]]
# sbatch:  [[4 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 5 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 0 4]]
# sbatch:  [[9 4 4]]
# sbatch:  [[8 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 9 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 0 4]]
# sbatch:  [[9 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 5 4]]
# sbatch:  [[9 8 4]]
# sbatch:  [[8 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 3 4]]
# sbatch:  [[8 2 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[0 2 1]]
# sbatch:  [[8 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 4]]
# sbatch:  [[8 7 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[2 5 1]]
# sbatch:  [[9 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[0 9 1]]
# sbatch:  [[9 5 4]]
# sbatch:  [[5 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[2 9 1]]
# sbatch:  [[0 6 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 1 1]]
# sbatch:  [[9 5 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 1 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 3 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[4 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 1]]
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 5 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 1]]
# sbatch:  [[9 2 4]]
# sbatch:  [[9 3 4]]
# sbatch:  [[8 0 4]]
# sbatch:  [[9 1 4]]
# sbatch:  [[9 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 4 4]]
# sbatch:  [[8 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 8 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 1]]
# sbatch:  [[9 1 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 0 4]]
# sbatch:  [[9 0 1]]
# sbatch:  [[5 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[2 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 1]]
# sbatch:  [[1 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 1 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[1 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[0 8 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[0 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[4 7 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[1 1 1]]
# sbatch:  [[8 8 4]]
# sbatch:  [[8 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 1 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[1 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 4 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 4 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[1 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 4 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 4]]
# sbatch:  [[9 5 4]]
# sbatch:  [[9 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 8 2]]
# sbatch:  [[7 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 5 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 4 4]]
# sbatch:  [[8 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[1 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[0 7 1]]
# sbatch:  [[7 8 2]]
# sbatch:  [[9 2 1]]
# sbatch:  [[7 1 1]]
# sbatch:  [[0 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 1 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[0 7 1]]
# sbatch:  [[8 0 1]]
# sbatch:  [[9 1 1]]
# sbatch:  [[7 1 1]]
# sbatch:  [[9 4 1]]
# sbatch:  [[8 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 5 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 4]]
# sbatch:  [[9 6 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 1]]
# sbatch:  [[0 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 7 1]]
# sbatch:  [[7 6 4]]
# sbatch:  [[9 2 1]]
# sbatch:  [[9 6 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 5 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[3 6 1]]
# sbatch:  [[9 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 3 4]]
# sbatch:  [[9 5 4]]
# sbatch:  [[9 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[2 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 1]]
# sbatch:  [[7 5 4]]
# sbatch:  [[8 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[4 9 1]]
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 5 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 8 1]]
# sbatch:  [[7 0 4]]
# sbatch:  [[7 8 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 1 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[0 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 5 4]]
# sbatch:  [[9 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 5 4]]
# sbatch:  [[7 1 1]]
# sbatch:  [[9 2 4]]
# sbatch:  [[6 0 1]]
# sbatch:  [[0 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 4 4]]
# sbatch:  [[8 1 1]]
# sbatch:  [[9 2 1]]
# sbatch:  [[7 7 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[1 6 1]]
# sbatch:  [[0 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 4 4]]
# sbatch:  [[9 9 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 6 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 5 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 4]]
# sbatch:  [[8 6 1]]
# sbatch:  [[8 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 9 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 8 2]]
# sbatch:  [[8 1 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[4 0 1]]
# sbatch:  [[7 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 8 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 1 1]]
# sbatch:  [[7 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 1]]
# sbatch:  [[6 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# sbatch:  [[9 6 4]]
# sbatch:  [[2 8 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 0 1]]
# sbatch:  [[7 7 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 3 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 1]]
# sbatch:  [[0 6 1]]
# sbatch:  [[8 1 1]]
# sbatch:  [[9 0 4]]
# sbatch:  [[8 1 1]]
# sbatch:  [[9 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 4 4]]
# sbatch:  [[6 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 1]]
# sbatch:  [[9 1 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 5 4]]
# sbatch:  [[7 1 4]]
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 1]]
# sbatch:  [[9 4 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[1 4 1]]
# sbatch:  [[9 9 4]]
# sbatch:  [[9 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 5 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 3 1]]
# sbatch:  [[9 4 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 0 4]]
# sbatch:  [[9 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 1]]
# sbatch:  [[8 4 4]]
# sbatch:  [[9 3 4]]
# sbatch:  [[9 2 4]]
# sbatch:  [[9 2 4]]
# sbatch:  [[9 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 3 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 7 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 1]]
# sbatch:  [[9 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 7 1]]
# sbatch:  [[8 1 1]]
# sbatch:  [[9 0 1]]
# sbatch:  [[7 5 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[4 9 1]]
# sbatch:  [[9 7 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 1]]
# sbatch:  [[9 5 4]]
# sbatch:  [[9 0 4]]
# sbatch:  [[9 7 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 5 4]]
# sbatch:  [[0 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 1]]
# sbatch:  [[7 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[2 5 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[1 0 1]]
# sbatch:  [[8 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 5 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 4 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 7 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 9 1]]
# sbatch:  [[9 6 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[4 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 1 1]]
# sbatch:  [[9 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[1 1 1]]
# sbatch:  [[9 2 4]]
# sbatch:  [[8 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[2 8 1]]
# sbatch:  [[8 5 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 6 1]]
# sbatch:  [[8 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 6 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 3 4]]
# sbatch:  [[8 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[0 6 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 6 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 4]]
# sbatch:  [[9 0 4]]
# sbatch:  [[9 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 3 4]]
# sbatch:  [[4 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 8 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 1 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 1 1]]
# sbatch:  [[9 1 1]]
# sbatch:  [[0 7 1]]
# sbatch:  [[9 5 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 8 1]]
# sbatch:  [[8 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 6 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 3 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[1 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 4 1]]
# sbatch:  [[8 1 4]]
# sbatch:  [[5 1 1]]
# sbatch:  [[9 4 4]]
# sbatch:  [[9 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 5 4]]
# sbatch:  [[0 9 1]]
# sbatch:  [[9 1 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 5 1]]
# sbatch:  [[3 8 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 6 4]]
# sbatch:  [[9 6 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 5 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 9 1]]
# sbatch:  [[9 2 1]]
# sbatch:  [[7 4 1]]
# sbatch:  [[7 0 4]]
# sbatch:  [[7 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 2 4]]
# sbatch:  [[9 5 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 9 4]]
# sbatch:  [[9 7 4]]
# sbatch:  [[9 4 1]]
# sbatch:  [[5 5 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 4 1]]
# sbatch:  [[9 4 1]]
# sbatch:  [[9 7 4]]
# sbatch:  [[9 4 4]]
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 7 1]]
# sbatch:  [[9 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 1 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 1 4]]
# sbatch:  [[5 9 2]]
# sbatch:  [[1 6 1]]
# sbatch:  [[7 5 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[4 9 1]]
# sbatch:  [[8 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 4 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 5 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[1 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 7 1]]
# sbatch:  [[1 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 0 1]]
# sbatch:  [[9 8 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 5 4]]
# sbatch:  [[9 6 1]]
# sbatch:  [[8 9 1]]
# sbatch:  [[9 2 4]]
# sbatch:  [[8 2 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 6 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 1]]
# sbatch:  [[8 4 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[1 8 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 9 1]]
# sbatch:  [[1 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 8 2]]
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 3 4]]
# sbatch:  [[9 9 1]]
# sbatch:  [[8 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 1]]
# sbatch:  [[9 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 3 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 5 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[0 6 1]]
# sbatch:  [[9 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 4 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 8 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[4 9 1]]
# sbatch:  [[1 6 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 6 1]]
# sbatch:  [[9 0 1]]
# sbatch:  [[9 2 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 3 1]]
# sbatch:  [[9 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 8 1]]
# sbatch:  [[9 3 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 9 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 3 1]]
# sbatch:  [[8 5 4]]
# sbatch:  [[9 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 4]]
# sbatch:  [[9 4 4]]
# sbatch:  [[9 1 1]]
# | Reward: -5000 | Episode: 1 | Qmax: 16.6364 | Exploration: 0.200000 | Step: 499 | LR: 0.00001000
# sbatch:  [[0 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 1]]
# sbatch:  [[9 1 1]]
# sbatch:  [[9 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 6 4]]
# sbatch:  [[9 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[0 8 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 1]]
# sbatch:  [[8 1 4]]
# sbatch:  [[9 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[4 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 4]]
# sbatch:  [[9 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 4]]
# sbatch:  [[8 6 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[3 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 1]]
# sbatch:  [[8 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[0 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 8 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# sbatch:  [[8 7 1]]
# sbatch:  [[9 6 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 8 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 1]]
# sbatch:  [[5 8 2]]
# sbatch:  [[9 9 1]]
# sbatch:  [[8 1 1]]
# sbatch:  [[8 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 4]]
# sbatch:  [[8 8 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 3 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 1 4]]
# sbatch:  [[8 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 1]]
# sbatch:  [[8 0 4]]
# sbatch:  [[9 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# sbatch:  [[8 2 1]]
# sbatch:  [[9 4 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[1 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 3 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 3 4]]
# sbatch:  [[9 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 1]]
# sbatch:  [[9 3 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 4 4]]
# sbatch:  [[8 9 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 3 1]]
# sbatch:  [[7 3 1]]
# sbatch:  [[4 2 1]]
# ...
# sbatch:  [[5 9 2]]
# sbatch:  [[9 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 3 1]]
# sbatch:  [[9 8 1]]
# sbatch:  [[8 8 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 9 1]]
# sbatch:  [[5 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 8 4]]
# sbatch:  [[8 8 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[2 8 4]]
# sbatch:  [[9 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 5 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 9 1]]
# sbatch:  [[7 0 1]]
# sbatch:  [[5 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[3 8 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 6 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 9 1]]
# sbatch:  [[8 8 1]]
# sbatch:  [[9 6 1]]
# sbatch:  [[9 8 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 5 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 9 1]]
# sbatch:  [[8 0 1]]
# sbatch:  [[2 9 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 3 1]]
# sbatch:  [[7 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[1 7 2]]
# sbatch:  [[6 9 1]]
# sbatch:  [[5 7 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# sbatch:  [[7 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[0 8 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 2 1]]
# sbatch:  [[1 9 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 3 1]]
# sbatch:  [[5 8 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 8 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 1]]
# sbatch:  [[3 9 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 8 4]]
# sbatch:  [[6 9 2]]
# sbatch:  [[9 9 1]]
# sbatch:  [[9 2 1]]
# sbatch:  [[8 5 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[0 8 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 9 1]]
# sbatch:  [[9 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[0 9 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[3 6 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 9 2]]
# sbatch:  [[4 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 9 1]]
# sbatch:  [[5 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 9 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 6 2]]
# sbatch:  [[7 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 6 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 9 1]]
# sbatch:  [[8 8 1]]
# sbatch:  [[8 1 4]]
# sbatch:  [[9 9 4]]
# sbatch:  [[9 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[3 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 8 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[3 9 1]]
# sbatch:  [[7 9 4]]
# sbatch:  [[6 5 1]]
# sbatch:  [[8 0 1]]
# sbatch:  [[3 7 2]]
# sbatch:  [[8 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 2 1]]
# sbatch:  [[7 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 7 1]]
# sbatch:  [[9 8 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[3 8 1]]
# sbatch:  [[6 0 1]]
# sbatch:  [[8 1 1]]
# sbatch:  [[0 6 2]]
# sbatch:  [[9 1 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 8 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[2 7 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[2 9 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 6 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 0 1]]
# sbatch:  [[4 9 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 3 1]]
# | Reward: -5270 | Episode: 12 | Qmax: 13.8891 | Exploration: 0.200000 | Step: 499 | LR: 0.00001000
# sbatch:  [[6 9 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 1]]
# sbatch:  [[9 9 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 2 1]]
# sbatch:  [[8 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 9 1]]
# sbatch:  [[7 2 1]]
# sbatch:  [[6 7 1]]
# sbatch:  [[9 8 1]]
# sbatch:  [[0 8 2]]
# sbatch:  [[1 9 1]]
# sbatch:  [[0 7 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[4 8 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 8 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 3 1]]
# sbatch:  [[1 8 2]]
# sbatch:  [[6 5 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 7 1]]
# sbatch:  [[9 3 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[2 9 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 7 2]]
# sbatch:  [[0 8 2]]
# sbatch:  [[9 8 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 6 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 9 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 5 1]]
# sbatch:  [[7 8 1]]
# sbatch:  [[9 2 1]]
# sbatch:  [[9 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 6 1]]
# sbatch:  [[4 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 1 1]]
# sbatch:  [[9 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 6 1]]
# sbatch:  [[9 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 2 1]]
# sbatch:  [[8 8 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[3 9 2]]
# sbatch:  [[5 3 2]]
# sbatch:  [[9 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 3 1]]
# sbatch:  [[9 0 4]]
# sbatch:  [[9 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# sbatch:  [[7 5 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 2 1]]
# sbatch:  [[9 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[3 9 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 3 1]]
# sbatch:  [[0 9 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 8 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 5 1]]
# sbatch:  [[7 3 1]]
# sbatch:  [[9 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[1 9 2]]
# sbatch:  [[8 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 8 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 6 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[1 3 1]]
# sbatch:  [[8 6 1]]
# sbatch:  [[5 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 1 1]]
# sbatch:  [[0 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[2 8 4]]
# sbatch:  [[6 2 1]]
# sbatch:  [[5 8 2]]
# sbatch:  [[4 1 1]]
# sbatch:  [[5 7 2]]
# sbatch:  [[8 5 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 7 1]]
# sbatch:  [[8 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[4 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[4 1 1]]
# sbatch:  [[8 5 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[4 9 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[1 8 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 8 1]]
# sbatch:  [[3 8 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 5 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[2 9 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 2 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 4 1]]
# sbatch:  [[9 6 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 9 1]]
# sbatch:  [[5 8 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 9 1]]
# sbatch:  [[7 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[2 9 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 0 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[1 9 4]]
# sbatch:  [[9 2 1]]
# sbatch:  [[6 6 4]]
# sbatch:  [[9 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 6 1]]
# sbatch:  [[5 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 7 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 4 1]]
# sbatch:  [[8 9 1]]
# sbatch:  [[4 8 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 9 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[4 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 8 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 9 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 9 4]]
# sbatch:  [[3 8 1]]
# sbatch:  [[0 9 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 9 1]]
# sbatch:  [[9 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[2 9 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 6 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 9 1]]
# sbatch:  [[8 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 8 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[2 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 8 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 9 1]]
# sbatch:  [[8 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 7 1]]
# sbatch:  [[6 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 8 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[4 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[2 8 2]]
# sbatch:  [[9 1 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 2 1]]
# sbatch:  [[9 5 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[4 8 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 9 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 4 1]]
# sbatch:  [[7 9 1]]
# sbatch:  [[8 2 1]]
# sbatch:  [[9 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 1 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 6 1]]
# sbatch:  [[9 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[2 9 2]]
# sbatch:  [[8 1 1]]
# sbatch:  [[1 9 1]]
# sbatch:  [[9 0 4]]
# sbatch:  [[0 9 2]]
# sbatch:  [[5 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 5 1]]
# sbatch:  [[8 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 8 2]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[5 8 1]]
# sbatch:  [[9 5 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 3 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 1 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[7 6 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[6 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 7 1]]
# sbatch:  [[7 7 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[1 8 4]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 8 3]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 1 1]]
# sbatch:  [[9 4 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 0 1]]
# sbatch:  [[7 2 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[8 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[9 7 4]]
# sbatch:  [[3 9 1]]
# sbatch:  [[9 2 1]]
# sbatch:  [[3 9 1]]
# sbatch:  [[5 9 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[3 2 1]]
# sbatch:  [[9 1 1]]
# sbatch:  [[9 0 1]]
# opt_rabin:  [1, 2, 3, 4]
# Current_Rabin:  1
# sbatch:  [[1 9 1]]
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-6-5f6356a33d08> in <module>()
#      18         Qnet = QNet(sess, state_dim, action_dim, LEARNING_RATE, TAU, MINIBATCH_SIZE, SAVE_DIR, DEVICE)
#      19
# ---> 20         train(sess, env, Qnet, prod_planner)
#
# <ipython-input-5-9c7ea34cb499> in train(sess, env, qnet, prod_planner)
#      58                 if rand_num > EXPLORATION_RATE + 0.9*GUIDE_RATE:
#      59                 # Only update global plan with 0.2 prob for efficiency
# ---> 60                     prod_planner.get_global_opt()
#      61                     prod_planner.get_opt_rabin()
#      62
#
# /d/DRA_Guide_Planning/dra_planning.pyc in get_global_opt(self)
#     114         except:
#     115             pass
# --> 116
#     117         # print 'Plan synthesized:'+str(opt_path)
#     118 #         return self.opt_path, self.region_list, self.wfts
#
# /d/DRA_Guide_Planning/full_prod_DRA.pyc in construct_fullproduct(self)
#     378                 if q_s not in self.transition.keys():
#     379                     self.transition[q_s] = {}
# --> 380                 if pi_i in self.wFTS.initial and q_m == self.Rabin.init_state:
#     381                     self.initial.add(q_s)
#     382                 if q_m in self.Rabin.accept:
#
# /d/DRA_Guide_Planning/full_prod_DRA.pyc in check_tran_b(self, b_state1, l, b_state2, Rabin)
#     389                         if q_g not in self.transition.keys():
#     390                             self.transition[q_g] = {}
# --> 391                         d = self.check_tran_b(q_m,self.wFTS.L(pi_i),q_n,self.Rabin)
#     392                         if d >= 0:
#     393                             self.transition[q_s][q_g] = self.wFTS.get_weight(pi_i,pi_j) + alpha*d
#
# /d/DRA_Guide_Planning/full_prod_DRA.pyc in get_transition_through_ap(self, state, ap)
#     238                             if j in ap or check_negations(seperated_j,neg_in_j,seperated_ap,neg_in_ap):
#     239                                 reachable_state.add(int(i))
# --> 240                         else:
#     241                             if j in ap or j=="true":
#     242                                 reachable_state.add(int(i))
#
# /d/DRA_Guide_Planning/full_prod_DRA.pyc in seperate_ap_sentence(input_str)
#      26             else:
#      27                 return [return_str],[]
# ---> 28         for i in range(1,len(index)):
#      29             return_str += [input_str[index[i-1]+1:index[i]]]
#      30         return_str = return_str + [input_str[index[-1]+1:]]
#
# KeyboardInterrupt:

# %%
env.reset()

# %%
env.s

# %%
np.where(np.array(prod_planner.opt_rabin) == 1)[0][0]

# %%
np.unravel_index(env.s,(10,10,5))

# %%
np.unravel_index(env.s,(10,10,5))

# %%
ns,r,_,_ = env.step(1)
print np.unravel_index(ns,(10,10,5)),r

# %%
prod_planner.get_global_opt()

# %%
env.ap_dict

# %%
env.last_ap_dict

# %%
env.last_dynamic_coord_dict[(2,2)]

# %%
env.rabin.coord_dict[(2,2)]

# %%
env.dynamic_coord_dict[(2,2)]

# %%
env.rabin.possible_states(1)

# %%
[env.rabin.graph[str(1)][str(0)][k]["label"] for k in range(len(env.rabin.graph[str(1)][str(0)]))]

# %%
env.rabin.check_ap("C", u' !A&!T&C')

# %%
env.rabin.graph["0"]["0"]

# %%
env._calculate_transition_prob((4, 3, 1), [0,1])

# %%
np.unravel_index(221,(10,10,5))

# %%
env.shape

# %%
current = (4,3,1)
delta=[0,1]
delta_list = [[-1, 0], [1, 0], [0, -1], [0, 1], [0, 0]]

# %%
new_position_candidates = [np.array(current[:2]) + np.array(delta)]
new_position_candidates += [np.array(current[:2]) + np.array(i) for i in delta_list if i != delta]

# %%
print new_positions

# %%
new_positions = [env._limit_coordinates(i).astype(int) for i in new_position_candidates]

# %%
next_rabin_state = [env.rabin.next_state(current, tuple(i)) for i in new_positions]

# %%
env.rabin.next_state((4,3,1),(4,4))

# %%
env.rabin.coord_dict[(2,7)]

# %%
env.rabin.next_state((4,3,1),[0,1])

# %%
env.rabin.deadlock

# %%
np.where(np.array(prod_planner.opt_rabin) == 8)[0]

# %%
env = CurrentWorld(LTL.lower())

# %%
prod_planner = Prod_Planning(env, LTL.lower())

# %%
prod_planner.update_wfts_ap()

# %%
env.dynamic_coord_dict[(5,5)]

# %%
env.last_dynamic_coord_dict[(5,5)]

# %%
prod_planner.region_list[np.ravel_multi_index((5,5),(10,10))].ap

# %%
env.ap_dict

# %%
env.last_ap_dict

# %%
env.step(1)
