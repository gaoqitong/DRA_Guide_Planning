# %%
import sys
sys.path.append("../")

# %%
from __future__ import division
from full_prod_DRA import *
from buchi import buchi_from_ltl
import numpy as np
from env_sensing_error_small import *
import scipy
# from plot_path_for_prod import *
from graphviz import Source
from qnetwork import *
from utils import *
import matplotlib.pyplot as plt
# from Plot_Path import *
import tensorflow as tf
import sys
from dra_planning import *
import time
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p27/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
def train(sess, env, qnet, prod_planner):
    
    global EXPLORATION_RATE
    global GUIDE_RATE
  
    summary_ops, summary_vars = build_summaries()
    if not RESTORE:
        sess.run(tf.global_variables_initializer())
    writer = tf.summary.FileWriter(SUMMARY_DIR, sess.graph)
    
    qnet.update_target()
    
    replay_buffer = ReplayBuffer(BUFFER_SIZE, RANDOM_SEED)
    
    while len(prod_planner.opt_path) == 0:
        env.step(np.random.randint(0,qnet.action_dim))
        prod_planner.update_wfts_ap()
        env.update_dynamic_rabin()
        prod_planner.get_global_opt()
    print "Global Solution Found"
    prod_planner.get_opt_rabin()
    
    saved_dra_planners = {}
    
    for num_epi in range(MAX_EPISODES):
        
#         print "Epi: ", num_epi

        s = env.reset()
        s = list(np.unravel_index(s, env.shape))
#         prod_planner.replace_region_list()
        prod_planner.update_wfts_ap()

        ep_reward = 0
        ep_ave_max_q = 0
        
        reward_list = []
        
        train_time = 0
        batch_time = 0
        gym_time = 0
        guide_time = 0

        for j in range(MAX_EPISODE_LEN):
            
#             print "Step: ", j
            
            gym_start = time.time()

            rand_num = np.random.rand(1)
    
            if rand_num <= EXPLORATION_RATE:
                a = np.random.randint(0,qnet.action_dim)
                s2, r, terminal, info = env.step(a)
                
            elif rand_num <= GUIDE_RATE+EXPLORATION_RATE and rand_num > EXPLORATION_RATE:
#                 print "GUIDE"
                guide_start = time.time()
                
                if rand_num > EXPLORATION_RATE + 0.9*GUIDE_RATE:
                # Only update global plan with 0.2 prob for efficiency
                    env.update_dynamic_rabin()
                    prod_planner.get_global_opt()
                    prod_planner.get_opt_rabin()
                    
                if len(prod_planner.opt_path) > 0:
#                     print "S: ", s
#                     print "last a: ", a
                    new_ltl = prod_planner.get_next_ltl(s[-1])
                    
#                     if new_ltl in saved_dra_planners.keys():
                    guide_path = prod_planner.get_local_opt(s[:-1], new_ltl)
                    if guide_path != None:
#                         print "GUIDE"
                        a = convert_path_to_action(guide_path)
                    else:
                        a = np.random.randint(0,qnet.action_dim)
#                     else:
#                         guide_path = prod_planner.get_local_opt(s[:-1], new_ltl)
#                         saved_dra_planners[new_ltl] = prod_planner.dra_full_prod
#                         if guide_path != None:
#                             a = convert_path_to_action(guide_path)
#                         else:
#                             a = np.random.randint(0,qnet.action_dim)
                        
                else:
                    a = np.random.randint(0,qnet.action_dim)
                
                s2, r, terminal, info = env.step(a)
                
                guide_time += time.time() - guide_start
                
            else:
                a = np.argmax(qnet.predict_q(np.reshape(s, (1, qnet.state_dim))))
                s2, r, terminal, info = env.step(a)

            prod_planner.update_wfts_ap()
                
            gym_time += time.time() - gym_start
            
            batch_start = time.time()
            
            s2 = list(np.unravel_index(s2, env.shape))

            replay_buffer.add(np.reshape(s, (qnet.state_dim,)), np.reshape(a, (1,)), r,
                              terminal, np.reshape(s2, (qnet.state_dim,)))
            batch_time += time.time() - batch_start

            # Keep adding experience to the memory until
            # there are at least minibatch size samples
            if replay_buffer.size() > MINIBATCH_SIZE:
                
                batch_start = time.time()
                s_batch, a_batch, r_batch, t_batch, s2_batch = replay_buffer.sample_batch(MINIBATCH_SIZE)
#                 print "sbatch: ", s_batch
                # Calculate targets
                target_q = qnet.predect_target(s2_batch)

                y_i = []
                for k in range(MINIBATCH_SIZE):
                    if t_batch[k]:
                        y_i.append(r_batch[k])
                    else:
                        y_i.append(r_batch[k] + GAMMA * np.amax(target_q[k]))
                        
                batch_time += time.time() - batch_start

                # Update the critic given the targets
                train_start = time.time()
                predicted_q_value, _ = qnet.train(s_batch, a_batch, np.reshape(y_i, (MINIBATCH_SIZE, 1)), num_epi)

                ep_ave_max_q += np.amax(predicted_q_value)
                
                # Update target networks
                qnet.update_target()

                train_time += time.time() - train_start

            s = s2
            ep_reward += r

            if terminal or j == MAX_EPISODE_LEN-1:
                
                if EXPLORATION_RATE > 0.02 and terminal:
                    EXPLORATION_RATE = EXPLORATION_RATE*0.98
                    GUIDE_RATE = GUIDE_RATE*0.98
                    
                reward_list += [ep_reward]
                
                if np.average(reward_list[-10:]) > LR_DECAY_TRUNCATION:
                    qnet.decay_learning_rate(0.98)

                print('| Reward: {:d} | Episode: {:d} | Qmax: {:.4f} | Exploration: {:.6f} | Step: {:d} | LR: {:.8f}'.format(int(ep_reward), \
                        num_epi, (ep_ave_max_q / float(j)), EXPLORATION_RATE, j, qnet.get_learning_rate()))
                
                f = open("stats/" + file_appendix + "_stats.txt", "ab")
                f.write("| Reward: " + str(int(ep_reward)) 
                        +" | Episode: " + str(num_epi) 
                        + " | Qmax: " + str(ep_ave_max_q / float(j)) 
                        + " | Exploration: " + str(EXPLORATION_RATE)
                        + " | Step: " + str(j)
                        + " | LR:" + str(qnet.get_learning_rate()) + "\n")
                f.close()
                
                f = open("stats/" + file_appendix + "_stats_time.txt", "ab")
                f.write(" | Episode: " + str(num_epi) 
                        + " | Train: " + str(train_time) 
                        + " | Gym: " + str(gym_time)
                        + " | Batch: " + str(batch_time) 
                        + " | Guide: " + str(guide_time)
                        + "\n")
                f.close()
                
                break

# %%
# LTL = "<>(A && <>(B && <> T)) && []<>A && []<>B"
# LTL = "[] (p1 -> !(X p1) U (p2 || p3) ) && []<>p1"
# LTL = "T && []<>A && []<>B"
# LTL = "<>(A && <>(B && <> T)) && []<>A && []<>B && []!C && []!D"
# LTL = "<>(A && <>(B && <> T)) && []<>A && []<>B && []!C"
# LTL = "<>(A && <>(B && <> T))"
# LTL = "<>(A && <>B) && <>[]T && []!C"
LTL = "<>(A && <>T) && []!C"
# LTL = "<>(A && <>(B && <>T)) && []<>(A||T) && []<>B && []!C"
# LTL = "<>(A && <>(B && <>T)) && []!C"
# LTL = "<>(A && <>D) && <>(B && <>E) && []<>T && []<>(D || E) && []!C"

LEARNING_RATE = 0.0015
GAMMA = 0.99
# GAMMA = 0.7
TAU = 0.001
BUFFER_SIZE = 10**6
MINIBATCH_SIZE = 64
RANDOM_SEED = 210
MAX_EPISODES = 50000
MAX_EPISODE_LEN = 200
file_appendix = "Guide_Planning_" + time.ctime()[4:16].replace("  ","").replace(" ","_").replace(":","-") + "_large_" + LTL
# file_appendix = "Feb8_03-47"
SUMMARY_DIR = './results/tf_ddqn_' + file_appendix
SAVE_DIR = "./saved_model/" + file_appendix + "/ddqn.ckpt"
EXPLORATION_RATE = 0.3
GUIDE_RATE = 0.5
LR_DECAY_TRUNCATION = -200
RESTORE = 0
if sys.platform == "darwin":
    DEVICE = "/device:CPU:0"
else:
    DEVICE = "/device:GPU:0"

# %%
env = CurrentWorld(LTL)
prod_planner = Prod_Planning(env, LTL)
# with open("my.dot", "r") as dotfile:
#     text = dotfile.read()
# Source(text)

# %%
config=tf.ConfigProto(log_device_placement=False)
config.gpu_options.allow_growth = True
with tf.Session(config=config) as sess:
       
    state_dim = 3
    action_dim = 5
    
    if RESTORE:
        Qnet = QNet(sess, state_dim, action_dim, LEARNING_RATE, TAU, MINIBATCH_SIZE, SAVE_DIR, DEVICE)
        Qnet.saver.restore(sess, RESTORE_PATH)
        train(sess, env, Qnet, prod_planner)
        
    else:
        np.random.seed(RANDOM_SEED)
        tf.set_random_seed(RANDOM_SEED)
        env.seed(RANDOM_SEED)
    
        Qnet = QNet(sess, state_dim, action_dim, LEARNING_RATE, TAU, MINIBATCH_SIZE, SAVE_DIR, DEVICE)

        train(sess, env, Qnet, prod_planner)
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p27/lib/python2.7/site-packages/tensorflow/python/ops/gradients_impl.py:112: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Global Solution Found
# | Reward: -1030 | Episode: 0 | Qmax: 0.0000 | Exploration: 0.294000 | Step: 50 | LR: 0.00150000
# | Reward: -100 | Episode: 1 | Qmax: 0.0000 | Exploration: 0.288120 | Step: 11 | LR: 0.00147000
# | Reward: -270 | Episode: 2 | Qmax: 10.3228 | Exploration: 0.282358 | Step: 10 | LR: 0.00147000
# | Reward: -400 | Episode: 3 | Qmax: 13.7677 | Exploration: 0.276710 | Step: 23 | LR: 0.00147000
# | Reward: -250 | Episode: 4 | Qmax: 18.7940 | Exploration: 0.271176 | Step: 17 | LR: 0.00147000
# | Reward: -470 | Episode: 5 | Qmax: 16.2406 | Exploration: 0.265753 | Step: 21 | LR: 0.00147000
# | Reward: -790 | Episode: 6 | Qmax: 15.3855 | Exploration: 0.260438 | Step: 35 | LR: 0.00147000
# | Reward: -840 | Episode: 7 | Qmax: 10.8583 | Exploration: 0.255229 | Step: 22 | LR: 0.00147000
# | Reward: -360 | Episode: 8 | Qmax: 8.8052 | Exploration: 0.250124 | Step: 19 | LR: 0.00147000
# | Reward: -2260 | Episode: 9 | Qmax: 59.1222 | Exploration: 0.245122 | Step: 173 | LR: 0.00147000
# | Reward: -390 | Episode: 10 | Qmax: 80.6476 | Exploration: 0.240219 | Step: 31 | LR: 0.00147000
# | Reward: -390 | Episode: 11 | Qmax: 84.4856 | Exploration: 0.235415 | Step: 40 | LR: 0.00147000
# | Reward: -140 | Episode: 12 | Qmax: 84.4174 | Exploration: 0.230707 | Step: 24 | LR: 0.00144060
# | Reward: -800 | Episode: 13 | Qmax: 83.9808 | Exploration: 0.226093 | Step: 63 | LR: 0.00144060
# | Reward: -370 | Episode: 14 | Qmax: 86.7252 | Exploration: 0.221571 | Step: 47 | LR: 0.00144060
# | Reward: -280 | Episode: 15 | Qmax: 95.7671 | Exploration: 0.217139 | Step: 38 | LR: 0.00144060
# | Reward: -230 | Episode: 16 | Qmax: 94.1802 | Exploration: 0.212797 | Step: 24 | LR: 0.00144060
# | Reward: -470 | Episode: 17 | Qmax: 89.4766 | Exploration: 0.208541 | Step: 39 | LR: 0.00144060
# | Reward: -150 | Episode: 18 | Qmax: 86.1379 | Exploration: 0.204370 | Step: 25 | LR: 0.00141179
# | Reward: -490 | Episode: 19 | Qmax: 92.3733 | Exploration: 0.200282 | Step: 59 | LR: 0.00141179
# DDQN Saved
# | Reward: -240 | Episode: 20 | Qmax: 88.3419 | Exploration: 0.196277 | Step: 34 | LR: 0.00141179
# | Reward: -560 | Episode: 21 | Qmax: 89.0783 | Exploration: 0.192351 | Step: 57 | LR: 0.00141179
# | Reward: -200 | Episode: 22 | Qmax: 96.7765 | Exploration: 0.188504 | Step: 30 | LR: 0.00141179
# | Reward: -100 | Episode: 23 | Qmax: 93.5239 | Exploration: 0.184734 | Step: 20 | LR: 0.00138355
# | Reward: -320 | Episode: 24 | Qmax: 96.6549 | Exploration: 0.181039 | Step: 42 | LR: 0.00138355
# | Reward: -160 | Episode: 25 | Qmax: 102.4335 | Exploration: 0.177419 | Step: 17 | LR: 0.00135588
# | Reward: -270 | Episode: 26 | Qmax: 93.6589 | Exploration: 0.173870 | Step: 28 | LR: 0.00135588
# | Reward: -140 | Episode: 27 | Qmax: 109.7336 | Exploration: 0.170393 | Step: 15 | LR: 0.00132876
# | Reward: -360 | Episode: 28 | Qmax: 99.3724 | Exploration: 0.166985 | Step: 28 | LR: 0.00132876
# | Reward: -120 | Episode: 29 | Qmax: 103.5799 | Exploration: 0.163645 | Step: 13 | LR: 0.00130219
# | Reward: -540 | Episode: 30 | Qmax: 103.9760 | Exploration: 0.160372 | Step: 46 | LR: 0.00130219
# | Reward: -190 | Episode: 31 | Qmax: 102.7505 | Exploration: 0.157165 | Step: 20 | LR: 0.00127614
# | Reward: -350 | Episode: 32 | Qmax: 92.2947 | Exploration: 0.154022 | Step: 18 | LR: 0.00127614
# | Reward: -2250 | Episode: 33 | Qmax: 99.2511 | Exploration: 0.150941 | Step: 181 | LR: 0.00127614
# | Reward: -1020 | Episode: 34 | Qmax: 97.8397 | Exploration: 0.147922 | Step: 76 | LR: 0.00127614
# | Reward: -210 | Episode: 35 | Qmax: 101.1919 | Exploration: 0.144964 | Step: 22 | LR: 0.00127614
# | Reward: -880 | Episode: 36 | Qmax: 100.1063 | Exploration: 0.142065 | Step: 80 | LR: 0.00127614
# | Reward: -2210 | Episode: 37 | Qmax: 96.6939 | Exploration: 0.139223 | Step: 168 | LR: 0.00127614
# | Reward: -180 | Episode: 38 | Qmax: 102.4082 | Exploration: 0.136439 | Step: 19 | LR: 0.00125062
# | Reward: -1390 | Episode: 39 | Qmax: 96.7495 | Exploration: 0.133710 | Step: 95 | LR: 0.00125062
# DDQN Saved
# | Reward: -630 | Episode: 40 | Qmax: 100.3632 | Exploration: 0.131036 | Step: 46 | LR: 0.00125062
# | Reward: -2360 | Episode: 41 | Qmax: 98.2431 | Exploration: 0.131036 | Step: 199 | LR: 0.00125062
# | Reward: -980 | Episode: 42 | Qmax: 100.0703 | Exploration: 0.128415 | Step: 90 | LR: 0.00125062
# | Reward: -2030 | Episode: 43 | Qmax: 99.8197 | Exploration: 0.125847 | Step: 105 | LR: 0.00125062
# | Reward: -1020 | Episode: 44 | Qmax: 100.4535 | Exploration: 0.123330 | Step: 67 | LR: 0.00125062
# | Reward: -600 | Episode: 45 | Qmax: 100.5641 | Exploration: 0.120863 | Step: 52 | LR: 0.00125062
# | Reward: -2280 | Episode: 46 | Qmax: 96.1355 | Exploration: 0.118446 | Step: 193 | LR: 0.00125062
# | Reward: -1170 | Episode: 47 | Qmax: 96.5850 | Exploration: 0.116077 | Step: 100 | LR: 0.00125062
# | Reward: -2130 | Episode: 48 | Qmax: 98.7606 | Exploration: 0.113756 | Step: 178 | LR: 0.00125062
# | Reward: -800 | Episode: 49 | Qmax: 101.0843 | Exploration: 0.111481 | Step: 63 | LR: 0.00125062
# | Reward: -1490 | Episode: 50 | Qmax: 98.0015 | Exploration: 0.109251 | Step: 132 | LR: 0.00125062
# | Reward: -2300 | Episode: 51 | Qmax: 99.1787 | Exploration: 0.107066 | Step: 186 | LR: 0.00125062
# | Reward: -2900 | Episode: 52 | Qmax: 100.8832 | Exploration: 0.107066 | Step: 199 | LR: 0.00125062
# | Reward: -2090 | Episode: 53 | Qmax: 98.3559 | Exploration: 0.107066 | Step: 199 | LR: 0.00125062
# | Reward: -2450 | Episode: 54 | Qmax: 98.4717 | Exploration: 0.107066 | Step: 199 | LR: 0.00125062
# | Reward: -2360 | Episode: 55 | Qmax: 100.6803 | Exploration: 0.107066 | Step: 199 | LR: 0.00125062
# | Reward: -2090 | Episode: 56 | Qmax: 99.7765 | Exploration: 0.107066 | Step: 199 | LR: 0.00125062
# | Reward: -2000 | Episode: 57 | Qmax: 100.6529 | Exploration: 0.107066 | Step: 199 | LR: 0.00125062
# | Reward: -2090 | Episode: 58 | Qmax: 95.5471 | Exploration: 0.107066 | Step: 199 | LR: 0.00125062
# | Reward: -2270 | Episode: 59 | Qmax: 98.7704 | Exploration: 0.107066 | Step: 199 | LR: 0.00125062
# DDQN Saved
# | Reward: -2270 | Episode: 60 | Qmax: 97.8878 | Exploration: 0.107066 | Step: 199 | LR: 0.00125062
# | Reward: -1430 | Episode: 61 | Qmax: 98.9762 | Exploration: 0.104925 | Step: 117 | LR: 0.00125062
# | Reward: -2110 | Episode: 62 | Qmax: 101.0164 | Exploration: 0.102826 | Step: 194 | LR: 0.00125062
# | Reward: -2360 | Episode: 63 | Qmax: 96.7014 | Exploration: 0.102826 | Step: 199 | LR: 0.00125062
# | Reward: -2630 | Episode: 64 | Qmax: 95.1223 | Exploration: 0.102826 | Step: 199 | LR: 0.00125062
# | Reward: -1620 | Episode: 65 | Qmax: 98.2353 | Exploration: 0.100770 | Step: 145 | LR: 0.00125062
# | Reward: -2360 | Episode: 66 | Qmax: 97.9209 | Exploration: 0.100770 | Step: 199 | LR: 0.00125062
# | Reward: -2360 | Episode: 67 | Qmax: 101.1294 | Exploration: 0.100770 | Step: 199 | LR: 0.00125062
# | Reward: -400 | Episode: 68 | Qmax: 97.0358 | Exploration: 0.098754 | Step: 50 | LR: 0.00125062
# | Reward: -480 | Episode: 69 | Qmax: 96.5861 | Exploration: 0.096779 | Step: 40 | LR: 0.00125062
# | Reward: -1400 | Episode: 70 | Qmax: 97.8562 | Exploration: 0.094843 | Step: 132 | LR: 0.00125062
# | Reward: -650 | Episode: 71 | Qmax: 96.8377 | Exploration: 0.092947 | Step: 75 | LR: 0.00125062
# | Reward: -1160 | Episode: 72 | Qmax: 99.0111 | Exploration: 0.091088 | Step: 90 | LR: 0.00125062
# | Reward: -240 | Episode: 73 | Qmax: 100.2838 | Exploration: 0.089266 | Step: 34 | LR: 0.00125062
# | Reward: -880 | Episode: 74 | Qmax: 97.1277 | Exploration: 0.087481 | Step: 98 | LR: 0.00125062
# | Reward: -200 | Episode: 75 | Qmax: 94.1512 | Exploration: 0.085731 | Step: 30 | LR: 0.00125062
# | Reward: -680 | Episode: 76 | Qmax: 100.3569 | Exploration: 0.084016 | Step: 78 | LR: 0.00125062
# | Reward: -70 | Episode: 77 | Qmax: 103.9688 | Exploration: 0.082336 | Step: 17 | LR: 0.00122561
# | Reward: -480 | Episode: 78 | Qmax: 99.4985 | Exploration: 0.080689 | Step: 49 | LR: 0.00122561
# | Reward: -20 | Episode: 79 | Qmax: 103.8733 | Exploration: 0.079076 | Step: 12 | LR: 0.00120110
# DDQN Saved
# | Reward: -320 | Episode: 80 | Qmax: 99.1913 | Exploration: 0.077494 | Step: 42 | LR: 0.00120110
# | Reward: -660 | Episode: 81 | Qmax: 95.1683 | Exploration: 0.075944 | Step: 76 | LR: 0.00120110
# | Reward: -250 | Episode: 82 | Qmax: 98.0046 | Exploration: 0.074425 | Step: 35 | LR: 0.00120110
# | Reward: -940 | Episode: 83 | Qmax: 96.5851 | Exploration: 0.072937 | Step: 104 | LR: 0.00120110
# | Reward: -660 | Episode: 84 | Qmax: 95.6366 | Exploration: 0.071478 | Step: 76 | LR: 0.00120110
# | Reward: -540 | Episode: 85 | Qmax: 99.3590 | Exploration: 0.070048 | Step: 55 | LR: 0.00120110
# | Reward: -1000 | Episode: 86 | Qmax: 97.5051 | Exploration: 0.068648 | Step: 110 | LR: 0.00120110
# | Reward: -370 | Episode: 87 | Qmax: 94.7985 | Exploration: 0.067275 | Step: 47 | LR: 0.00120110
# | Reward: -80 | Episode: 88 | Qmax: 105.8912 | Exploration: 0.065929 | Step: 18 | LR: 0.00117708
# | Reward: -2000 | Episode: 89 | Qmax: 95.7938 | Exploration: 0.065929 | Step: 199 | LR: 0.00117708
# | Reward: -2000 | Episode: 90 | Qmax: 95.0417 | Exploration: 0.065929 | Step: 199 | LR: 0.00117708
# | Reward: -40 | Episode: 91 | Qmax: 105.6677 | Exploration: 0.064610 | Step: 14 | LR: 0.00115353
# | Reward: -120 | Episode: 92 | Qmax: 99.9876 | Exploration: 0.063318 | Step: 22 | LR: 0.00113046
# | Reward: -110 | Episode: 93 | Qmax: 102.0838 | Exploration: 0.062052 | Step: 21 | LR: 0.00110785
# | Reward: -90 | Episode: 94 | Qmax: 101.0221 | Exploration: 0.060811 | Step: 19 | LR: 0.00108570
# | Reward: -650 | Episode: 95 | Qmax: 96.6935 | Exploration: 0.059595 | Step: 75 | LR: 0.00108570
# | Reward: -180 | Episode: 96 | Qmax: 100.1761 | Exploration: 0.058403 | Step: 28 | LR: 0.00106398
# | Reward: 0 | Episode: 97 | Qmax: 107.4510 | Exploration: 0.057235 | Step: 10 | LR: 0.00104270
# | Reward: 0 | Episode: 98 | Qmax: 94.1042 | Exploration: 0.056090 | Step: 10 | LR: 0.00102185
# | Reward: 0 | Episode: 99 | Qmax: 107.1773 | Exploration: 0.054968 | Step: 10 | LR: 0.00100141
# DDQN Saved
# | Reward: 0 | Episode: 100 | Qmax: 106.9506 | Exploration: 0.053869 | Step: 10 | LR: 0.00098138
# | Reward: 0 | Episode: 101 | Qmax: 109.9605 | Exploration: 0.052791 | Step: 10 | LR: 0.00096176
# | Reward: -40 | Episode: 102 | Qmax: 110.1273 | Exploration: 0.051736 | Step: 14 | LR: 0.00094252
# | Reward: -960 | Episode: 103 | Qmax: 94.4330 | Exploration: 0.050701 | Step: 97 | LR: 0.00094252
# | Reward: 0 | Episode: 104 | Qmax: 106.3090 | Exploration: 0.049687 | Step: 10 | LR: 0.00092367
# | Reward: 0 | Episode: 105 | Qmax: 104.9518 | Exploration: 0.048693 | Step: 10 | LR: 0.00090520
# | Reward: -100 | Episode: 106 | Qmax: 102.7573 | Exploration: 0.047719 | Step: 11 | LR: 0.00088709
# | Reward: 0 | Episode: 107 | Qmax: 111.5199 | Exploration: 0.046765 | Step: 10 | LR: 0.00086935
# | Reward: 0 | Episode: 108 | Qmax: 102.1729 | Exploration: 0.045830 | Step: 10 | LR: 0.00085196
# | Reward: -30 | Episode: 109 | Qmax: 103.1811 | Exploration: 0.044913 | Step: 13 | LR: 0.00083493
# | Reward: -30 | Episode: 110 | Qmax: 110.3573 | Exploration: 0.044015 | Step: 13 | LR: 0.00081823
# | Reward: -20 | Episode: 111 | Qmax: 109.2242 | Exploration: 0.043134 | Step: 12 | LR: 0.00080186
# | Reward: 0 | Episode: 112 | Qmax: 107.1191 | Exploration: 0.042272 | Step: 10 | LR: 0.00078583
# | Reward: 0 | Episode: 113 | Qmax: 104.4742 | Exploration: 0.041426 | Step: 10 | LR: 0.00077011
# | Reward: -20 | Episode: 114 | Qmax: 107.4055 | Exploration: 0.040598 | Step: 12 | LR: 0.00075471
# | Reward: 0 | Episode: 115 | Qmax: 98.9807 | Exploration: 0.039786 | Step: 10 | LR: 0.00073961
# | Reward: -20 | Episode: 116 | Qmax: 105.8599 | Exploration: 0.038990 | Step: 12 | LR: 0.00072482
# | Reward: -1000 | Episode: 117 | Qmax: 99.4250 | Exploration: 0.038210 | Step: 110 | LR: 0.00072482
# | Reward: 0 | Episode: 118 | Qmax: 109.3743 | Exploration: 0.037446 | Step: 10 | LR: 0.00071032
# | Reward: 0 | Episode: 119 | Qmax: 107.1575 | Exploration: 0.036697 | Step: 10 | LR: 0.00069612
# DDQN Saved
# | Reward: -10 | Episode: 120 | Qmax: 121.6383 | Exploration: 0.035963 | Step: 11 | LR: 0.00068219
# | Reward: -2090 | Episode: 121 | Qmax: 98.4503 | Exploration: 0.035963 | Step: 199 | LR: 0.00068219
# | Reward: 0 | Episode: 122 | Qmax: 101.8620 | Exploration: 0.035244 | Step: 10 | LR: 0.00066855
# | Reward: 0 | Episode: 123 | Qmax: 105.8762 | Exploration: 0.034539 | Step: 10 | LR: 0.00065518
# | Reward: 0 | Episode: 124 | Qmax: 107.2281 | Exploration: 0.033848 | Step: 10 | LR: 0.00064208
# | Reward: 0 | Episode: 125 | Qmax: 107.8784 | Exploration: 0.033171 | Step: 10 | LR: 0.00062923
# | Reward: 0 | Episode: 126 | Qmax: 106.8434 | Exploration: 0.032508 | Step: 10 | LR: 0.00061665
# | Reward: 0 | Episode: 127 | Qmax: 107.3004 | Exploration: 0.031858 | Step: 10 | LR: 0.00060432
# | Reward: 0 | Episode: 128 | Qmax: 100.1088 | Exploration: 0.031221 | Step: 10 | LR: 0.00059223
# | Reward: -20 | Episode: 129 | Qmax: 104.3405 | Exploration: 0.030596 | Step: 12 | LR: 0.00058039
# | Reward: 0 | Episode: 130 | Qmax: 103.1495 | Exploration: 0.029984 | Step: 10 | LR: 0.00056878
# | Reward: 0 | Episode: 131 | Qmax: 110.4855 | Exploration: 0.029385 | Step: 10 | LR: 0.00055740
# | Reward: 0 | Episode: 132 | Qmax: 105.9797 | Exploration: 0.028797 | Step: 10 | LR: 0.00054626
# | Reward: -40 | Episode: 133 | Qmax: 102.6164 | Exploration: 0.028221 | Step: 14 | LR: 0.00053533
# | Reward: 0 | Episode: 134 | Qmax: 95.2935 | Exploration: 0.027657 | Step: 10 | LR: 0.00052462
# | Reward: -20 | Episode: 135 | Qmax: 108.9277 | Exploration: 0.027103 | Step: 12 | LR: 0.00051413
# | Reward: -20 | Episode: 136 | Qmax: 108.3319 | Exploration: 0.026561 | Step: 12 | LR: 0.00050385
# | Reward: 0 | Episode: 137 | Qmax: 100.8059 | Exploration: 0.026030 | Step: 10 | LR: 0.00049377
# | Reward: 0 | Episode: 138 | Qmax: 107.0432 | Exploration: 0.025510 | Step: 10 | LR: 0.00048390
# | Reward: 0 | Episode: 139 | Qmax: 106.9836 | Exploration: 0.024999 | Step: 10 | LR: 0.00047422
# DDQN Saved
# | Reward: 0 | Episode: 140 | Qmax: 106.9564 | Exploration: 0.024499 | Step: 10 | LR: 0.00046473
# | Reward: 0 | Episode: 141 | Qmax: 103.2133 | Exploration: 0.024009 | Step: 10 | LR: 0.00045544
# | Reward: 0 | Episode: 142 | Qmax: 101.9118 | Exploration: 0.023529 | Step: 10 | LR: 0.00044633
# | Reward: 0 | Episode: 143 | Qmax: 103.6185 | Exploration: 0.023059 | Step: 10 | LR: 0.00043740
# | Reward: 0 | Episode: 144 | Qmax: 112.2386 | Exploration: 0.022597 | Step: 10 | LR: 0.00042866
# | Reward: 0 | Episode: 145 | Qmax: 109.1073 | Exploration: 0.022145 | Step: 10 | LR: 0.00042008
# | Reward: 0 | Episode: 146 | Qmax: 110.5870 | Exploration: 0.021703 | Step: 10 | LR: 0.00041168
# | Reward: 0 | Episode: 147 | Qmax: 109.1164 | Exploration: 0.021269 | Step: 10 | LR: 0.00040345
# | Reward: 0 | Episode: 148 | Qmax: 112.3873 | Exploration: 0.020843 | Step: 10 | LR: 0.00039538
# | Reward: 0 | Episode: 149 | Qmax: 109.4986 | Exploration: 0.020426 | Step: 10 | LR: 0.00038747
# | Reward: 0 | Episode: 150 | Qmax: 109.9028 | Exploration: 0.020018 | Step: 10 | LR: 0.00037972
# | Reward: -20 | Episode: 151 | Qmax: 104.5751 | Exploration: 0.019617 | Step: 12 | LR: 0.00037213
# | Reward: 0 | Episode: 152 | Qmax: 104.5627 | Exploration: 0.019617 | Step: 10 | LR: 0.00036468
# | Reward: 0 | Episode: 153 | Qmax: 102.7952 | Exploration: 0.019617 | Step: 10 | LR: 0.00035739
# | Reward: -20 | Episode: 154 | Qmax: 106.0362 | Exploration: 0.019617 | Step: 12 | LR: 0.00035024
# | Reward: 0 | Episode: 155 | Qmax: 109.0303 | Exploration: 0.019617 | Step: 10 | LR: 0.00034324
# | Reward: 0 | Episode: 156 | Qmax: 108.2419 | Exploration: 0.019617 | Step: 10 | LR: 0.00033637
# | Reward: 0 | Episode: 157 | Qmax: 103.2159 | Exploration: 0.019617 | Step: 10 | LR: 0.00032965
# | Reward: 0 | Episode: 158 | Qmax: 101.1810 | Exploration: 0.019617 | Step: 10 | LR: 0.00032305
# | Reward: 0 | Episode: 159 | Qmax: 108.5498 | Exploration: 0.019617 | Step: 10 | LR: 0.00031659
# DDQN Saved
# | Reward: 0 | Episode: 160 | Qmax: 105.6499 | Exploration: 0.019617 | Step: 10 | LR: 0.00031026
# | Reward: -10 | Episode: 161 | Qmax: 108.3718 | Exploration: 0.019617 | Step: 11 | LR: 0.00030405
# | Reward: -10 | Episode: 162 | Qmax: 106.6640 | Exploration: 0.019617 | Step: 11 | LR: 0.00029797
# | Reward: 0 | Episode: 163 | Qmax: 104.1560 | Exploration: 0.019617 | Step: 10 | LR: 0.00029201
# | Reward: 0 | Episode: 164 | Qmax: 106.2306 | Exploration: 0.019617 | Step: 10 | LR: 0.00028617
# | Reward: 0 | Episode: 165 | Qmax: 107.6117 | Exploration: 0.019617 | Step: 10 | LR: 0.00028045
# | Reward: -20 | Episode: 166 | Qmax: 107.0759 | Exploration: 0.019617 | Step: 12 | LR: 0.00027484
# | Reward: 0 | Episode: 167 | Qmax: 101.0420 | Exploration: 0.019617 | Step: 10 | LR: 0.00026934
# | Reward: 0 | Episode: 168 | Qmax: 106.7392 | Exploration: 0.019617 | Step: 10 | LR: 0.00026396
# | Reward: 0 | Episode: 169 | Qmax: 107.3605 | Exploration: 0.019617 | Step: 10 | LR: 0.00025868
# | Reward: 0 | Episode: 170 | Qmax: 108.8726 | Exploration: 0.019617 | Step: 10 | LR: 0.00025351
# | Reward: 0 | Episode: 171 | Qmax: 108.4868 | Exploration: 0.019617 | Step: 10 | LR: 0.00024844
# | Reward: 0 | Episode: 172 | Qmax: 105.4870 | Exploration: 0.019617 | Step: 10 | LR: 0.00024347
# | Reward: 0 | Episode: 173 | Qmax: 104.7790 | Exploration: 0.019617 | Step: 10 | LR: 0.00023860
# | Reward: 0 | Episode: 174 | Qmax: 110.3274 | Exploration: 0.019617 | Step: 10 | LR: 0.00023383
# | Reward: 0 | Episode: 175 | Qmax: 108.4799 | Exploration: 0.019617 | Step: 10 | LR: 0.00022915
# | Reward: 0 | Episode: 176 | Qmax: 109.4595 | Exploration: 0.019617 | Step: 10 | LR: 0.00022457
# | Reward: 0 | Episode: 177 | Qmax: 106.7502 | Exploration: 0.019617 | Step: 10 | LR: 0.00022007
# | Reward: 0 | Episode: 178 | Qmax: 103.4360 | Exploration: 0.019617 | Step: 10 | LR: 0.00021567
# | Reward: 0 | Episode: 179 | Qmax: 109.5747 | Exploration: 0.019617 | Step: 10 | LR: 0.00021136
# DDQN Saved
# | Reward: 0 | Episode: 180 | Qmax: 107.0424 | Exploration: 0.019617 | Step: 10 | LR: 0.00020713
# | Reward: -10 | Episode: 181 | Qmax: 106.8090 | Exploration: 0.019617 | Step: 11 | LR: 0.00020299
# | Reward: 0 | Episode: 182 | Qmax: 110.3041 | Exploration: 0.019617 | Step: 10 | LR: 0.00019893
# | Reward: -10 | Episode: 183 | Qmax: 106.3562 | Exploration: 0.019617 | Step: 11 | LR: 0.00019495
# | Reward: 0 | Episode: 184 | Qmax: 103.4936 | Exploration: 0.019617 | Step: 10 | LR: 0.00019105
# | Reward: 0 | Episode: 185 | Qmax: 110.1568 | Exploration: 0.019617 | Step: 10 | LR: 0.00018723
# | Reward: 0 | Episode: 186 | Qmax: 110.4748 | Exploration: 0.019617 | Step: 10 | LR: 0.00018349
# | Reward: -10 | Episode: 187 | Qmax: 105.8927 | Exploration: 0.019617 | Step: 11 | LR: 0.00017982
# | Reward: 0 | Episode: 188 | Qmax: 112.3033 | Exploration: 0.019617 | Step: 10 | LR: 0.00017622
# | Reward: 0 | Episode: 189 | Qmax: 107.4914 | Exploration: 0.019617 | Step: 10 | LR: 0.00017270
# | Reward: 0 | Episode: 190 | Qmax: 101.1684 | Exploration: 0.019617 | Step: 10 | LR: 0.00016924
# | Reward: 0 | Episode: 191 | Qmax: 108.5456 | Exploration: 0.019617 | Step: 10 | LR: 0.00016586
# | Reward: 0 | Episode: 192 | Qmax: 107.7131 | Exploration: 0.019617 | Step: 10 | LR: 0.00016254
# | Reward: 0 | Episode: 193 | Qmax: 110.3180 | Exploration: 0.019617 | Step: 10 | LR: 0.00015929
# | Reward: 0 | Episode: 194 | Qmax: 111.1670 | Exploration: 0.019617 | Step: 10 | LR: 0.00015610
# | Reward: 0 | Episode: 195 | Qmax: 107.3520 | Exploration: 0.019617 | Step: 10 | LR: 0.00015298
# | Reward: 0 | Episode: 196 | Qmax: 105.6734 | Exploration: 0.019617 | Step: 10 | LR: 0.00014992
# | Reward: 0 | Episode: 197 | Qmax: 112.7016 | Exploration: 0.019617 | Step: 10 | LR: 0.00014692
# | Reward: 0 | Episode: 198 | Qmax: 106.1487 | Exploration: 0.019617 | Step: 10 | LR: 0.00014399
# | Reward: 0 | Episode: 199 | Qmax: 106.4483 | Exploration: 0.019617 | Step: 10 | LR: 0.00014111
# DDQN Saved
# | Reward: 0 | Episode: 200 | Qmax: 107.5994 | Exploration: 0.019617 | Step: 10 | LR: 0.00013828
# | Reward: 0 | Episode: 201 | Qmax: 105.0589 | Exploration: 0.019617 | Step: 10 | LR: 0.00013552
# | Reward: -10 | Episode: 202 | Qmax: 108.3536 | Exploration: 0.019617 | Step: 11 | LR: 0.00013281
# | Reward: 0 | Episode: 203 | Qmax: 108.4293 | Exploration: 0.019617 | Step: 10 | LR: 0.00013015
# | Reward: -20 | Episode: 204 | Qmax: 107.5769 | Exploration: 0.019617 | Step: 12 | LR: 0.00012755
# | Reward: 0 | Episode: 205 | Qmax: 111.5580 | Exploration: 0.019617 | Step: 10 | LR: 0.00012500
# | Reward: 0 | Episode: 206 | Qmax: 113.5669 | Exploration: 0.019617 | Step: 10 | LR: 0.00012250
# | Reward: 0 | Episode: 207 | Qmax: 107.8854 | Exploration: 0.019617 | Step: 10 | LR: 0.00012005
# | Reward: 0 | Episode: 208 | Qmax: 108.2796 | Exploration: 0.019617 | Step: 10 | LR: 0.00011765
# | Reward: 0 | Episode: 209 | Qmax: 110.6099 | Exploration: 0.019617 | Step: 10 | LR: 0.00011529
# | Reward: 0 | Episode: 210 | Qmax: 108.0944 | Exploration: 0.019617 | Step: 10 | LR: 0.00011299
# | Reward: 0 | Episode: 211 | Qmax: 106.6354 | Exploration: 0.019617 | Step: 10 | LR: 0.00011073
# | Reward: 0 | Episode: 212 | Qmax: 108.5125 | Exploration: 0.019617 | Step: 10 | LR: 0.00010851
# | Reward: 0 | Episode: 213 | Qmax: 112.2053 | Exploration: 0.019617 | Step: 10 | LR: 0.00010634
# | Reward: 0 | Episode: 214 | Qmax: 105.0849 | Exploration: 0.019617 | Step: 10 | LR: 0.00010422
# | Reward: 0 | Episode: 215 | Qmax: 105.8946 | Exploration: 0.019617 | Step: 10 | LR: 0.00010213
# | Reward: 0 | Episode: 216 | Qmax: 108.8426 | Exploration: 0.019617 | Step: 10 | LR: 0.00010009
# | Reward: 0 | Episode: 217 | Qmax: 106.9948 | Exploration: 0.019617 | Step: 10 | LR: 0.00009809
# | Reward: -70 | Episode: 218 | Qmax: 108.7339 | Exploration: 0.019617 | Step: 8 | LR: 0.00009613
# | Reward: 0 | Episode: 219 | Qmax: 108.9582 | Exploration: 0.019617 | Step: 10 | LR: 0.00009420
# DDQN Saved
# | Reward: 0 | Episode: 220 | Qmax: 106.9827 | Exploration: 0.019617 | Step: 10 | LR: 0.00009232
# | Reward: 0 | Episode: 221 | Qmax: 109.7087 | Exploration: 0.019617 | Step: 10 | LR: 0.00009047
# | Reward: 0 | Episode: 222 | Qmax: 111.1565 | Exploration: 0.019617 | Step: 10 | LR: 0.00008866
# | Reward: 0 | Episode: 223 | Qmax: 110.7799 | Exploration: 0.019617 | Step: 10 | LR: 0.00008689
# | Reward: 0 | Episode: 224 | Qmax: 111.5010 | Exploration: 0.019617 | Step: 10 | LR: 0.00008515
# | Reward: 0 | Episode: 225 | Qmax: 115.8124 | Exploration: 0.019617 | Step: 10 | LR: 0.00008345
# | Reward: 0 | Episode: 226 | Qmax: 106.1361 | Exploration: 0.019617 | Step: 10 | LR: 0.00008178
# | Reward: 0 | Episode: 227 | Qmax: 106.7328 | Exploration: 0.019617 | Step: 10 | LR: 0.00008014
# | Reward: 0 | Episode: 228 | Qmax: 109.6487 | Exploration: 0.019617 | Step: 10 | LR: 0.00007854
# | Reward: 0 | Episode: 229 | Qmax: 111.7573 | Exploration: 0.019617 | Step: 10 | LR: 0.00007697
# | Reward: 0 | Episode: 230 | Qmax: 108.0296 | Exploration: 0.019617 | Step: 10 | LR: 0.00007543
# | Reward: -20 | Episode: 231 | Qmax: 109.0932 | Exploration: 0.019617 | Step: 12 | LR: 0.00007392
# | Reward: -20 | Episode: 232 | Qmax: 110.0589 | Exploration: 0.019617 | Step: 12 | LR: 0.00007244
# | Reward: -90 | Episode: 233 | Qmax: 100.0739 | Exploration: 0.019617 | Step: 10 | LR: 0.00007100
# | Reward: 0 | Episode: 234 | Qmax: 108.4375 | Exploration: 0.019617 | Step: 10 | LR: 0.00006958
# | Reward: -20 | Episode: 235 | Qmax: 107.2027 | Exploration: 0.019617 | Step: 12 | LR: 0.00006818
# | Reward: 0 | Episode: 236 | Qmax: 108.3058 | Exploration: 0.019617 | Step: 10 | LR: 0.00006682
# | Reward: -20 | Episode: 237 | Qmax: 108.1414 | Exploration: 0.019617 | Step: 12 | LR: 0.00006548
# | Reward: 0 | Episode: 238 | Qmax: 112.9519 | Exploration: 0.019617 | Step: 10 | LR: 0.00006417
# | Reward: 0 | Episode: 239 | Qmax: 112.3169 | Exploration: 0.019617 | Step: 10 | LR: 0.00006289
# DDQN Saved
# | Reward: 0 | Episode: 240 | Qmax: 104.9311 | Exploration: 0.019617 | Step: 10 | LR: 0.00006163
# | Reward: 0 | Episode: 241 | Qmax: 106.0649 | Exploration: 0.019617 | Step: 10 | LR: 0.00006040
# | Reward: 0 | Episode: 242 | Qmax: 109.5042 | Exploration: 0.019617 | Step: 10 | LR: 0.00005919
# | Reward: 0 | Episode: 243 | Qmax: 110.8583 | Exploration: 0.019617 | Step: 10 | LR: 0.00005801
# | Reward: 0 | Episode: 244 | Qmax: 111.1768 | Exploration: 0.019617 | Step: 10 | LR: 0.00005685
# | Reward: 0 | Episode: 245 | Qmax: 111.2580 | Exploration: 0.019617 | Step: 10 | LR: 0.00005571
# | Reward: 0 | Episode: 246 | Qmax: 102.3493 | Exploration: 0.019617 | Step: 10 | LR: 0.00005460
# | Reward: 0 | Episode: 247 | Qmax: 118.6929 | Exploration: 0.019617 | Step: 10 | LR: 0.00005351
# | Reward: 0 | Episode: 248 | Qmax: 117.2381 | Exploration: 0.019617 | Step: 10 | LR: 0.00005244
# | Reward: 0 | Episode: 249 | Qmax: 110.1829 | Exploration: 0.019617 | Step: 10 | LR: 0.00005139
# | Reward: 0 | Episode: 250 | Qmax: 112.7994 | Exploration: 0.019617 | Step: 10 | LR: 0.00005036
# | Reward: -20 | Episode: 251 | Qmax: 107.7347 | Exploration: 0.019617 | Step: 12 | LR: 0.00004935
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-6-5f6356a33d08> in <module>()
#      18         Qnet = QNet(sess, state_dim, action_dim, LEARNING_RATE, TAU, MINIBATCH_SIZE, SAVE_DIR, DEVICE)
#      19
# ---> 20         train(sess, env, Qnet, prod_planner)
#
# <ipython-input-3-53fb2d72c487> in train(sess, env, qnet, prod_planner)
#     115 #                 print "sbatch: ", s_batch
#     116                 # Calculate targets
# --> 117                 target_q = qnet.predect_target(s2_batch)
#     118
#     119                 y_i = []
#
# /d/DRA_Guide_Planning/qnetwork.pyc in predect_target(self, states)
#      91
#      92     def predect_target(self, states):
# ---> 93         return self.sess.run(self.target_q_values, feed_dict={self.target_inputs: states})
#      94
#      95     def update_target(self):
#
# /home/ubuntu/anaconda3/envs/tensorflow_p27/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/ubuntu/anaconda3/envs/tensorflow_p27/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# /home/ubuntu/anaconda3/envs/tensorflow_p27/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /home/ubuntu/anaconda3/envs/tensorflow_p27/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# /home/ubuntu/anaconda3/envs/tensorflow_p27/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# /home/ubuntu/anaconda3/envs/tensorflow_p27/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
while len(prod_planner.opt_path) == 0:
    env.step(np.random.randint(0,5))
    prod_planner.update_wfts_ap()
    env.update_dynamic_rabin()
    prod_planner.get_global_opt()
print "Global Solution Found"
prod_planner.get_opt_rabin()

# saved_dra_planners = {}

for num_epi in range(MAX_EPISODES):

#         print "Epi: ", num_epi

    s = env.reset()
    s = list(np.unravel_index(s, env.shape))
#         prod_planner.replace_region_list()
    prod_planner.update_wfts_ap()

    ep_reward = 0
    ep_ave_max_q = 0

    reward_list = []

    train_time = 0
    batch_time = 0
    gym_time = 0
    guide_time = 0

    for j in range(MAX_EPISODE_LEN):

#             print "Step: ", j

        gym_start = time.time()

        rand_num = np.random.rand(1)

        guide_start = time.time()

        if rand_num > 0.5:
        # Only update global plan with 0.2 prob for efficiency
            env.update_dynamic_rabin()
            prod_planner.get_global_opt()
            prod_planner.get_opt_rabin()

        if len(prod_planner.opt_path) > 0:
#                     print "S: ", s
#                     print "last a: ", a
            new_ltl = prod_planner.get_next_ltl(s[-1])

#                     if new_ltl in saved_dra_planners.keys():
            guide_path = prod_planner.get_local_opt(s[:-1], new_ltl)
            if guide_path != None:
                print "GUIDE"
                a = convert_path_to_action(guide_path)
            else:
                a = np.random.randint(0,5)
#                     else:
#                         guide_path = prod_planner.get_local_opt(s[:-1], new_ltl)
#                         saved_dra_planners[new_ltl] = prod_planner.dra_full_prod
#                         if guide_path != None:
#                             a = convert_path_to_action(guide_path)
#                         else:
#                             a = np.random.randint(0,qnet.action_dim)

        else:
            a = np.random.randint(0,5)
 
        s2, r, terminal, info = env.step(a)
        print s,a,list(np.unravel_index(s2, env.shape)),r,terminal,info

        guide_time += time.time() - guide_start


        prod_planner.update_wfts_ap()

        gym_time += time.time() - gym_start

        batch_start = time.time()

        s2 = list(np.unravel_index(s2, env.shape))

#         replay_buffer.add(np.reshape(s, (qnet.state_dim,)), np.reshape(a, (1,)), r,
#                           terminal, np.reshape(s2, (qnet.state_dim,)))
        batch_time += time.time() - batch_start

        # Keep adding experience to the memory until
        # there are at least minibatch size samples

        s = s2
        ep_reward += r

        if terminal or j == MAX_EPISODE_LEN-1:
            
            print "FINISH"

#             if EXPLORATION_RATE > 0.02 and terminal:
#                 EXPLORATION_RATE = EXPLORATION_RATE*0.98
#                 GUIDE_RATE = GUIDE_RATE*0.98

            reward_list += [ep_reward]

#             if np.average(reward_list[-10:]) > LR_DECAY_TRUNCATION:
#                 qnet.decay_learning_rate(0.98)

            print('| Reward: {:d} | Episode: {:d} | Qmax: {:.4f} | Exploration: {:.6f} | Step: {:d} | LR: {:.8f}'.format(int(ep_reward), \
                    num_epi, (ep_ave_max_q / float(j)), EXPLORATION_RATE, j, 0.00))

#             f = open("stats/" + file_appendix + "_stats.txt", "ab")
#             f.write("| Reward: " + str(int(ep_reward)) 
#                     +" | Episode: " + str(num_epi) 
#                     + " | Qmax: " + str(ep_ave_max_q / float(j)) 
#                     + " | Exploration: " + str(EXPLORATION_RATE)
#                     + " | Step: " + str(j)
#                     + " | LR:" + str(qnet.get_learning_rate()) + "\n")
#             f.close()

#             f = open("stats/" + file_appendix + "_stats_time.txt", "ab")
#             f.write(" | Episode: " + str(num_epi) 
#                     + " | Train: " + str(train_time) 
#                     + " | Gym: " + str(gym_time)
#                     + " | Batch: " + str(batch_time) 
#                     + " | Guide: " + str(guide_time)
#                     + "\n")
#             f.close()

            break

# %%
prod_planner.opt_path

# %%
env.ap_dict
